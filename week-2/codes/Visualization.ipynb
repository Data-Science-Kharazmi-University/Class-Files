# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Plot**

# %%
x = [1,2,5,6]
y = [1,4,25, 36]
plt.plot(x,y)

# %%
x = [1,5,2,6]
y = [1,25,4,36]
plt.plot(x,y)

# %%
x = [1,5,2,6]
y = [1,25,4,36]
plt.plot(x,y,'ro')

# %% [markdown]
# **Histoghram**

# %%
x = np.random.randn(100)
plt.hist(x,edgecolor = "white")
# Out:
# (array([ 4.,  3., 14., 13., 12., 24., 13., 11.,  4.,  2.]),
#  array([-2.43698224, -1.93214353, -1.42730482, -0.92246612, -0.41762741,
#          0.0872113 ,  0.59205001,  1.09688872,  1.60172742,  2.10656613,
#          2.61140484]),
#  <BarContainer object of 10 artists>)

# %%
x = np.random.randn(1000)
plt.hist(x,edgecolor = "white")
# Out:
# (array([  1.,   1.,  28., 117., 209., 287., 226., 100.,  27.,   4.]),
#  array([-4.06375074, -3.32793   , -2.59210925, -1.8562885 , -1.12046775,
#         -0.38464701,  0.35117374,  1.08699449,  1.82281524,  2.55863599,
#          3.29445673]),
#  <BarContainer object of 10 artists>)

# %%
d1 = pd.read_csv("student-dataset.csv")
d1

# %%
d1.columns
# Out:
# Index(['id', 'name', 'nationality', 'city', 'latitude', 'longitude', 'gender',
#        'age', 'english.grade', 'math.grade', 'sciences.grade',
#        'language.grade', 'portfolio.rating', 'coverletter.rating',
#        'refletter.rating'],
#       dtype='object')

# %%
plt.hist(d1["math.grade"],edgecolor="white")
# Out:
# (array([ 6., 10., 13., 18., 25., 27., 32., 44., 71., 61.]),
#  array([2.1 , 2.29, 2.48, 2.67, 2.86, 3.05, 3.24, 3.43, 3.62, 3.81, 4.  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(d1['gender'] edgecolor="white")
# Out:
# (array([152.,   0.,   0.,   0., 151.,   0.,   0.,   4.]),
#  array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  ]),
#  <BarContainer object of 8 artists>)

# %%
plt.hist(d1['nationality'],edgecolor="white")
# Out:
# (array([215.,  27.,  23.,  10.,   9.,   5.,   7.,   3.,   4.,   4.]),
#  array([ 0.,  3.,  6.,  9., 12., 15., 18., 21., 24., 27., 30.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(d1['nationality'],edgecolor="white", orientation='horizontal')
# Out:
# (array([215.,  27.,  23.,  10.,   9.,   5.,   7.,   3.,   4.,   4.]),
#  array([ 0.,  3.,  6.,  9., 12., 15., 18., 21., 24., 27., 30.]),
#  <BarContainer object of 10 artists>)

# %%
d1.nationality.unique()
# Out:
# array(['China', 'United States of America', 'Brazil', 'Philippines',
#        'Turkey', 'Mexico', 'Japan', 'Canada', 'Pakistan',
#        'Dominican Republic', 'India', 'Peru', 'Russian Federation',
#        'Spain', 'Poland', 'Korea (Republic of)', 'Cuba', 'Tunisia',
#        'Myanmar', 'Colombia', 'El Salvador', 'Germany', 'Bangladesh',
#        'Egypt', 'Ukraine', 'United Kingdom', 'Morocco', 'Netherlands',
#        'Chile', 'Thailand', 'Nicaragua'], dtype=object)

# %%
d1.groupby(["nationality"]).size()
# Out:
# nationality
# Bangladesh                    1
# Brazil                        9
# Canada                        7
# Chile                         1
# China                        13
# Colombia                      5
# Cuba                          1
# Dominican Republic            1
# Egypt                         1
# El Salvador                   1
# Germany                       1
# India                         8
# Japan                        13
# Korea (Republic of)           3
# Mexico                       24
# Morocco                       1
# Myanmar                       1
# Netherlands                   1
# Nicaragua                     1
# Pakistan                      3
# Peru                          1
# Philippines                   1
# Poland                        1
# Russian Federation            6
# Spain                         2
# Thailand                      1
# Tunisia                       1
# Turkey                        2
# Ukraine                       1
# United Kingdom                2
# United States of America    193
# dtype: int64

# %%
len(d1.nationality.unique())
# Out:
# 31

# %%
plt.hist(d1['nationality'],edgecolor="white", bins = 31, orientation='horizontal')
# Out:
# (array([ 13., 193.,   9.,   1.,   2.,  24.,  13.,   7.,   3.,   1.,   8.,
#           1.,   6.,   2.,   1.,   3.,   1.,   1.,   1.,   5.,   1.,   1.,
#           1.,   1.,   1.,   2.,   1.,   1.,   1.,   1.,   1.]),
#  array([ 0.        ,  0.96774194,  1.93548387,  2.90322581,  3.87096774,
#          4.83870968,  5.80645161,  6.77419355,  7.74193548,  8.70967742,
#          9.67741935, 10.64516129, 11.61290323, 12.58064516, 13.5483871 ,
#         14.51612903, 15.48387097, 16.4516129 , 17.41935484, 18.38709677,
#         19.35483871, 20.32258065, 21.29032258, 22.25806452, 23.22580645,
#         24.19354839, 25.16129032, 26.12903226, 27.09677419, 28.06451613,
#         29.03225806, 30.        ]),
#  <BarContainer object of 31 artists>)

# %%
x = d1.groupby(["nationality"]).size()
x.plot(kind='bar')
# Out:
# <Axes: xlabel='nationality'>

# %%
x = d1.groupby(["portfolio.rating"]).size()
x.plot(kind='bar')
# Out:
# <Axes: xlabel='portfolio.rating'>

# %%
#plt.bar(x, height, width, bottom, align)

# creating the dataset
data = {'C':20, 'C++':15, 'Java':30,
        'Python':35}
courses = list(data.keys())
values = list(data.values())

# creating the bar plot
plt.bar(courses, values, color ='maroon',
        width = 0.4)
# Out:
# <BarContainer object of 4 artists>

# %%
 d2 = d1.describe()
# Out:
#                id    latitude   longitude         age  english.grade  \
# count  307.000000  307.000000  307.000000  307.000000     307.000000
# mean   153.000000   32.863388  -64.539121   21.964169       3.369707
# std     88.767487   13.498582   81.249146    1.248013       0.538724
# min      0.000000  -33.450000 -123.130000   19.000000       1.500000
# 25%     76.500000   32.720000 -118.240000   21.000000       3.100000
# 50%    153.000000   34.390000  -99.140000   22.000000       3.500000
# 75%    229.500000   38.960000  -73.855000   23.000000       3.800000
# max    306.000000   59.890000  139.750000   26.000000       4.000000
#
#        math.grade  sciences.grade  language.grade  portfolio.rating  \
# count  307.000000      307.000000      307.000000        307.000000
# mean     3.414332        3.446580        4.396417          3.986971
# std      0.476839        0.509081        0.996474          0.928749
# min      2.100000        1.400000        1.000000          1.000000
# 25%      3.100000        3.200000        4.000000          3.500000
# 50%      3.500000        3.600000        5.000000          4.000000
# 75%      3.800000        3.800000        5.000000          5.000000
# max      4.000000        4.000000        5.000000          5.000000
#
#        coverletter.rating  refletter.rating
# count          307.000000        307.000000
# mean             4.110749          4.188925
# std              0.823936          0.842193
# min              1.000000          1.000000
# 25%              4.000000          4.000000
# 50%              4.000000          4.000000
# 75%              5.000000          5.000000
# max              5.000000          5.000000

# %%
l = d2.columns
m = d2.loc["mean",:]
print(l)
print(m)
# Out:
# Index(['id', 'latitude', 'longitude', 'age', 'english.grade', 'math.grade',
#        'sciences.grade', 'language.grade', 'portfolio.rating',
#        'coverletter.rating', 'refletter.rating'],
#       dtype='object')
# id                    153.000000
# latitude               32.863388
# longitude             -64.539121
# age                    21.964169
# english.grade           3.369707
# math.grade              3.414332
# sciences.grade          3.446580
# language.grade          4.396417
# portfolio.rating        3.986971
# coverletter.rating      4.110749
# refletter.rating        4.188925
# Name: mean, dtype: float64

# %%
plt.bar(l,m)
# Out:
# <BarContainer object of 11 artists>

# %%
fig = plt.figure(figsize =(10, 7))
plt.bar(l,m)
# Out:
# <BarContainer object of 10 artists>

# %%
d2 = d2.drop(columns = ['id'])

# %%
l = d2.columns
m = d2.loc["mean",:]
plt.barh(l,m)
# Out:
# <BarContainer object of 10 artists>

# %%
np.random.seed(10)
data = np.random.normal(100, 20, 200)

fig = plt.figure(figsize =(10, 7))

# Creating plot
plt.boxplot(data)

# %% [markdown]
# **Boxplot**

# %%
x = plt.boxplot(d1['math.grade'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-120-8f39c8a365e6> in <cell line: 2>()
#       1 x = plt.boxplot(d1['math.grade'])
# ----> 2 x.show()
#
# AttributeError: 'dict' object has no attribute 'show'

# %%
plt.boxplot(d1['latitude'])
plt.show()

# %%
data = pd.read_csv("diabetes.csv")
data.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
plt.subplot(2,3,1)
plt.boxplot(data["Glucose"])
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
plt.subplot(2,3,1)
plt.boxplot(data["Glucose"])
plt.title("Glucose")
plt.subplot(2,3,2)
plt.boxplot(data["BloodPressure"])
plt.title("BloodPressure")
plt.subplot(2,3,3)
plt.boxplot(data["SkinThickness"])
plt.title("SkinThickness")
plt.subplot(2,3,4)
plt.boxplot(data["Insulin"])
plt.title("Insulin")
plt.subplot(2,3,5)
plt.boxplot(data["BMI"])
plt.title("BMI")
plt.subplot(2,3,6)
plt.boxplot(data["Age"])
plt.title("Age")
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
plt.subplot(2,2,1)
plt.boxplot(data["Insulin"])
plt.title("Insulin boxplot")
plt.subplot(2,2,2)
plt.hist(data["Insulin"])
plt.title("Insulin histogram")
plt.subplot(2,2,3)
plt.boxplot(data["Glucose"])
plt.title("Glucose boxplot")
plt.subplot(2,2,4)
plt.hist(data["Glucose"])
plt.title("Glucose histogram")
plt.show
# Out:
# Text(0.5, 1.0, 'histogram')

# %%
data.Outcome.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
xd = data[data.Outcome == 1]["Glucose"].tolist()
xnd = data.loc[data.Outcome == 0]["Glucose"].tolist()
xd
# Out:
# [148,
#  183,
#  137,
#  78,
#  197,
#  125,
#  168,
#  189,
#  166,
#  100,
#  118,
#  107,
#  115,
#  196,
#  119,
#  143,
#  125,
#  147,
#  158,
#  102,
#  90,
#  111,
#  171,
#  180,
#  103,
#  176,
#  187,
#  133,
#  114,
#  109,
#  100,
#  126,
#  131,
#  137,
#  136,
#  134,
#  122,
#  163,
#  95,
#  171,
#  155,
#  160,
#  146,
#  124,
#  162,
#  113,
#  88,
#  117,
#  105,
#  173,
#  122,
#  170,
#  108,
#  156,
#  188,
#  152,
#  163,
#  131,
#  104,
#  102,
#  134,
#  179,
#  129,
#  130,
#  194,
#  181,
#  128,
#  109,
#  139,
#  159,
#  135,
#  158,
#  107,
#  109,
#  148,
#  196,
#  162,
#  184,
#  140,
#  112,
#  151,
#  109,
#  85,
#  112,
#  177,
#  158,
#  162,
#  142,
#  134,
#  171,
#  181,
#  179,
#  164,
#  139,
#  119,
#  184,
#  92,
#  113,
#  155,
#  141,
#  123,
#  138,
#  146,
#  101,
#  106,
#  146,
#  161,
#  108,
#  119,
#  107,
#  128,
#  128,
#  146,
#  100,
#  167,
#  144,
#  115,
#  161,
#  128,
#  124,
#  155,
#  109,
#  182,
#  194,
#  112,
#  124,
#  152,
#  122,
#  102,
#  180,
#  115,
#  152,
#  178,
#  0,
#  165,
#  125,
#  129,
#  196,
#  189,
#  146,
#  124,
#  133,
#  173,
#  140,
#  156,
#  116,
#  105,
#  144,
#  166,
#  158,
#  131,
#  193,
#  95,
#  136,
#  168,
#  115,
#  197,
#  172,
#  138,
#  173,
#  144,
#  129,
#  151,
#  184,
#  181,
#  95,
#  141,
#  189,
#  108,
#  117,
#  180,
#  104,
#  134,
#  175,
#  148,
#  120,
#  105,
#  158,
#  145,
#  135,
#  125,
#  195,
#  0,
#  180,
#  84,
#  163,
#  145,
#  130,
#  132,
#  129,
#  100,
#  128,
#  90,
#  186,
#  187,
#  125,
#  198,
#  121,
#  118,
#  197,
#  151,
#  124,
#  143,
#  176,
#  111,
#  132,
#  188,
#  173,
#  150,
#  183,
#  181,
#  174,
#  168,
#  138,
#  112,
#  119,
#  114,
#  104,
#  97,
#  147,
#  167,
#  179,
#  136,
#  155,
#  80,
#  199,
#  167,
#  145,
#  115,
#  145,
#  111,
#  195,
#  156,
#  121,
#  162,
#  125,
#  144,
#  158,
#  129,
#  142,
#  169,
#  125,
#  168,
#  115,
#  164,
#  93,
#  129,
#  187,
#  173,
#  97,
#  149,
#  130,
#  120,
#  174,
#  102,
#  120,
#  140,
#  147,
#  187,
#  162,
#  136,
#  181,
#  154,
#  128,
#  123,
#  190,
#  170,
#  126]

# %%
class_data = pd.DataFrame({'Diabeties' : [xd], 'Normal':[xnd]})
class_data
# Out:
#                                            Diabeties  \
# 0  [148, 183, 137, 78, 197, 125, 168, 189, 166, 1...
#
#                                               Normal
# 0  [85, 89, 116, 115, 110, 139, 103, 126, 99, 97,...
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['Diabeties', 'Normal'],)"
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_0.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')

# %%
plt.boxplot(
    # A data frame needs to be converted to an array before it can be plotted this way
    np.array(class_data),
    # You can use the column headings from the data frame as labels
    labels=list(class_data)
)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-183-57b3d3c5a941> in <cell line: 2>()
#       1 fig = plt.figure(figsize =(10, 7))
# ----> 2 plt.boxplot(
#       3     # A data frame needs to be converted to an array before it can be plotted this way
#       4     np.array(class_data),
#       5     # You can use the column headings from the data frame as labels
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, data)
#    2481         whiskerprops=None, manage_ticks=True, autorange=False,
#    2482         zorder=None, capwidths=None, *, data=None):
# -> 2483     return gca().boxplot(
#    2484         x, notch=notch, sym=sym, vert=vert, whis=whis,
#    2485         positions=positions, widths=widths, patch_artist=patch_artist,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths)
#    3912             bootstrap = mpl.rcParams['boxplot.bootstrap']
#    3913
# -> 3914         bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
#    3915                                        labels=labels, autorange=autorange)
#    3916         if notch is None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1233
#    1234         # medians and quartiles
# -> 1235         q1, med, q3 = np.percentile(x, [25, 50, 75])
#    1236
#    1237         # interquartile range
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py in percentile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    4281     if not _quantile_is_valid(q):
#    4282         raise ValueError("Percentiles must be in the range [0, 100]")
# -> 4283     return _quantile_unchecked(
#    4284         a, q, axis, out, overwrite_input, method, keepdims)
#    4285
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    4553                         keepdims=False):
#    4554     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4555     return _ureduce(a,
#    4556                     func=_quantile_ureduce_func,
#    4557                     q=q,
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py in _ureduce(a, func, keepdims, **kwargs)
#    3821                 kwargs['out'] = out[(Ellipsis, ) + index_out]
#    3822
# -> 3823     r = func(a, **kwargs)
#    3824
#    3825     if out is not None:
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py in _quantile_ureduce_func(a, q, axis, out, overwrite_input, method)
#    4720         else:
#    4721             arr = a.copy()
# -> 4722     result = _quantile(arr,
#    4723                        quantiles=q,
#    4724                        axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py in _quantile(arr, quantiles, axis, method, out)
#    4839         result_shape = virtual_indexes.shape + (1,) * (arr.ndim - 1)
#    4840         gamma = gamma.reshape(result_shape)
# -> 4841         result = _lerp(previous,
#    4842                        next,
#    4843                        gamma,
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py in _lerp(a, b, t, out)
#    4653         Output array.
#    4654     """
# -> 4655     diff_b_a = subtract(b, a)
#    4656     # asanyarray is a stop-gap until gh-13105
#    4657     lerp_interpolation = asanyarray(add(a, diff_b_a * t, out=out))
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
import seaborn as sns

# %%
sns.set_style("whitegrid")
sns.boxplot(data, x='Outcome', y='Glucose')
# Out:
# <Axes: xlabel='Outcome', ylabel='Glucose'>

# %%
sns.set_style("whitegrid")
sns.boxplot(data, x='Outcome', y='BMI', palette="Set1")
# Out:
# <ipython-input-220-02d56dd24fde>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data, x='Outcome', y='BMI', palette="Set1")
# <Axes: xlabel='Outcome', ylabel='BMI'>

# %%
sns.set_style("whitegrid")
sns.boxplot(data, x='Outcome', y='BloodPressure', hue= "Outcome", palette="Set1", )
# Out:
# <Axes: xlabel='Outcome', ylabel='BloodPressure'>

# %%
sns.set(style='whitegrid')
sns.boxplot(data, x='Outcome', y='Age', palette="Set1")
# Out:
# <ipython-input-224-8533b8ed349e>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot( x='Outcome', y='Age', data = data, palette="Set1")
# <Axes: xlabel='Outcome', ylabel='Age'>

# %%
sns.countplot(d1 , x="portfolio.rating")
# Out:
# <Axes: xlabel='portfolio.rating', ylabel='count'>

# %%
sns.countplot(d1 , x="refletter.rating")
# Out:
# <Axes: xlabel='refletter.rating', ylabel='count'>

# %%
d1.columns
# Out:
# Index(['id', 'name', 'nationality', 'city', 'latitude', 'longitude', 'gender',
#        'age', 'english.grade', 'math.grade', 'sciences.grade',
#        'language.grade', 'portfolio.rating', 'coverletter.rating',
#        'refletter.rating'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# **Scatter plot**

# %%
plt.scatter(data.Glucose,data.Insulin)

# %%
plt.plot(data.Glucose,data.Insulin,'go')

# %%
plt.scatter(data.BMI,data.Glucose,marker ="^")

plt.show()

# %%
plt.scatter(data.BMI,data.Insulin)
plt.title("Scetter plot", fontdict = {"fontsize": 22 , "color" : "red"})
plt.xlabel("BMI")
plt.ylabel("Glucose")
plt.show()

# %%
col = np.where(data.Outcome == 1 ,'b','r')
plt.scatter(data.BMI,data.Glucose,c = col)
plt.title("Scetter plot")
plt.xlabel("BMI")
plt.ylabel("Glucose")

plt.show()

# %%
col = np.where(data.Outcome == 1 ,'b','r')
fig = plt.scatter(data.BloodPressure,data.Glucose, c= col)
plt.title("Scetter plot")
plt.xlabel("BloodPressure")
plt.ylabel("Glucose")
plt.savefig("scatter1.pdf")

plt.show()
